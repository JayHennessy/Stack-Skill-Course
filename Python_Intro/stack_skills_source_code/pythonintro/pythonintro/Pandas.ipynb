# %%
import pandas as pd

# %%
df = pd.read_csv('london_weather.csv')

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30               NaN               NaN
# 1              2  1996-07-01              19.0              11.0
# 2              3  1996-07-02              20.0              10.0
# 3              4  1996-07-03              19.0              12.0
# 4              5  1996-07-04              19.0              12.0
# 5              6  1996-07-05               NaN              11.0
# 6              7  1996-07-06              19.0              11.0
# 7              8  1996-07-07              19.0              11.0
# 8              9  1996-07-08              20.0              11.0
# 9             10  1996-07-09              21.0              12.0
# 10            11  1996-07-10              26.0              13.0
# 11            12  1996-07-11              24.0              15.0
# 12            13  1996-07-12              23.0              15.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0           1  1996-06-30               NaN               NaN
# 1           2  1996-07-01              19.0              11.0
# 2           3  1996-07-02              20.0              10.0
# 3           4  1996-07-03              19.0              12.0
# 4           5  1996-07-04              19.0              12.0
#
#    Max.Gust.SpeedKPH Events  Season
# 0                NaN    NaN  Summer
# 1               28.0   Rain  Summer
# 2                NaN    NaN  Summer
# 3                NaN   Rain  Summer
# 4               25.0   Rain  Summer

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 1378        1383  2000-06-26               NaN              13.0
# 1379        1384  2000-06-27              22.0              11.0
# 1380        1385  2000-06-28              21.0              13.0
# 1381        1386  2000-06-29              20.0              14.0
# 1382        1387  2000-06-30              20.0              14.0
#
#       Max.Gust.SpeedKPH             Events  Season
# 1378                NaN               Rain  Summer
# 1379                NaN                NaN  Summer
# 1380                NaN                NaN  Summer
# 1381                NaN  Rain-Thunderstorm  Summer
# 1382                NaN               Rain  Summer

# %%
print(len(df.index))
# Out:
# 1383

# %%
rainy_days = df['Date'][df['Events'] == 'Rain']

# %%
len(rainy_days)
# Out:
# 688

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('classic')
df['Max.TemperatureC'].plot()
plt.show()

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30               NaN               NaN
# 1              2  1996-07-01              19.0              11.0
# 2              3  1996-07-02              20.0              10.0
# 3              4  1996-07-03              19.0              12.0
# 4              5  1996-07-04              19.0              12.0
# 5              6  1996-07-05               NaN              11.0
# 6              7  1996-07-06              19.0              11.0
# 7              8  1996-07-07              19.0              11.0
# 8              9  1996-07-08              20.0              11.0
# 9             10  1996-07-09              21.0              12.0
# 10            11  1996-07-10              26.0              13.0
# 11            12  1996-07-11              24.0              15.0
# 12            13  1996-07-12              23.0              15.0
# ...

# %%
df['Max.TemperatureC'].fillna(df['Max.TemperatureC'].mean(), inplace=True)

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30         15.505102               NaN
# 1              2  1996-07-01         19.000000              11.0
# 2              3  1996-07-02         20.000000              10.0
# 3              4  1996-07-03         19.000000              12.0
# 4              5  1996-07-04         19.000000              12.0
# 5              6  1996-07-05         15.505102              11.0
# 6              7  1996-07-06         19.000000              11.0
# 7              8  1996-07-07         19.000000              11.0
# 8              9  1996-07-08         20.000000              11.0
# 9             10  1996-07-09         21.000000              12.0
# 10            11  1996-07-10         26.000000              13.0
# 11            12  1996-07-11         24.000000              15.0
# 12            13  1996-07-12         23.000000              15.0
# ...

# %%
style.use('Solarize_Light2')
df['Max.TemperatureC'].plot()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
import json
import requests
from pprint import pprint

url = 'http://api.openweathermap.org/data/2.5/forecast'
paramDict = {'q': 'London,UK', 'units': 'metric', 'appid': '5d4de404dbbe5bf7025ad72715503f15', 'cnt': 30}

response = requests.get(url, params=paramDict)
#assert response.status_code == 200
parsed_json = response.json();
pprint(parsed_json)
# Out:
# {'city': {'coord': {'lat': 51.5085, 'lon': -0.1258},
#           'country': 'GB',
#           'id': 2643743,
#           'name': 'London',
#           'population': 1000000},
#  'cnt': 30,
#  'cod': '200',
#  'list': [{'clouds': {'all': 64},
#            'dt': 1518166800,
#            'dt_txt': '2018-02-09 09:00:00',
#            'main': {'grnd_level': 1011.33,
#                     'humidity': 100,
#                     'pressure': 1011.33,
#                     'sea_level': 1019.03,
#                     'temp': 3.3,
#                     'temp_kf': -0.04,
#                     'temp_max': 3.33,
#                     'temp_min': 3.3},
#            'rain': {'3h': 0.055},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 266.5, 'speed': 5.81}},
#           {'clouds': {'all': 92},
# ...

# %%
from pandas.io.json import json_normalize

# %%
df = json_normalize(parsed_json['list'])
df
# Out:
#     clouds.all          dt               dt_txt  main.grnd_level  \
# 0           64  1518166800  2018-02-09 09:00:00          1011.33
# 1           92  1518177600  2018-02-09 12:00:00          1011.25
# 2           92  1518188400  2018-02-09 15:00:00          1014.76
# 3           92  1518199200  2018-02-09 18:00:00          1018.55
# 4            0  1518210000  2018-02-09 21:00:00          1021.49
# 5            0  1518220800  2018-02-10 00:00:00          1022.97
# 6            0  1518231600  2018-02-10 03:00:00          1023.10
# 7            0  1518242400  2018-02-10 06:00:00          1022.52
# 8           56  1518253200  2018-02-10 09:00:00          1021.36
# 9           92  1518264000  2018-02-10 12:00:00          1018.23
# 10          92  1518274800  2018-02-10 15:00:00          1014.04
# 11          92  1518285600  2018-02-10 18:00:00          1010.19
# 12          92  1518296400  2018-02-10 21:00:00          1008.08
# ...

# %%
max = df['main.temp_max'].max()
max
# Out:
# 8.5500000000000007
